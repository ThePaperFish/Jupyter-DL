# %% [markdown]
# # Interesting history of Visual
# -------

# %% [markdown]
# ## First sign of vision

# %% [markdown]
# 5 million ago, when there is only bateria.
# Eye become the key to get them evolve.
# - Catch food.
# - Escape from catcher

# %% [markdown]
# ## Camera Obscura

# %% [markdown]
# the first camera, capturing photo by light through a hole. by Da Vinci.

# %% [markdown]
# ## Discover of action of Vision's Neural

# %% [markdown]
# Hubul and Wiesel find out how the neural work to process vision. They find out what neural work not capturing the whole shape of image but just a simple shape like a single line.
# ![image.png](attachment:image.png)

# %% [markdown]
# Vision take part of half of brain to process, which is the biggest process compared to the others sensors.

# %% [markdown]
# ## Block World

# %% [markdown]
# Lary Roberts - trying to process image in computer.
